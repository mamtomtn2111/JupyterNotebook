# %%
import pandas as pd
from datetime import date, datetime 
import random

# %%
QB = pd.read_excel("C:\\Users\\mamto\\OneDrive\\Máy tính\\DataExcelProject1\\Three.xlsx")
display(QB)
# Out:
#       Unnamed: 0    id    trinhdo                             phanloai    ten  \
# 0              0     1     Sơ cấp                Liệt kê và tương phản  A/V-고
# 1              1     2     Sơ cấp                Liệt kê và tương phản   V-거나
# 2              2     3  Trung cấp    1, Diễn tả phỏng đoán và suy đoán  A/V-고
# 3              3     4  Trung cấp             2, Diễn tả sự tương phản   V-거나
# 4              4     5  Trung cấp        3, Thể trần thuật và thân mật  A/V-고
# ...          ...   ...        ...                                  ...    ...
# 1030        1030  1031    Cao cấp     18, Diễn tả hồi tưởng và kết quả    NaN
# 1031        1031  1032    Cao cấp  19, Diễn tả tiêu chuẩn và tình hình    NaN
# 1032        1032  1033    Cao cấp             20, Diễn tả sự nhấn mạnh    NaN
# 1033        1033  1034    Cao cấp          21, Diễn tả cách nói đề cao    NaN
# 1034        1034  1035    Cao cấp      22, Các biểu hiện hữu dụng khác    NaN
#
# ...

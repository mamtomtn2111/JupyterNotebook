# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
#D:\Work\Dự án Đh Kyungpook\Tuan4\Data\owid-covid-data.csv

# %%
CovidWorld = pd.read_csv("D:\\Work\\Dự án Đh Kyungpook\\Tuan4\\Data\\owid-covid-data.csv")
display(CovidWorld.head(10))
print(CovidWorld.columns)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# 5      AFG      Asia  Afghanistan  2020-02-29          5.0        0.0
# 6      AFG      Asia  Afghanistan  2020-03-01          5.0        0.0
# 7      AFG      Asia  Afghanistan  2020-03-02          5.0        0.0
# 8      AFG      Asia  Afghanistan  2020-03-03          5.0        0.0
# 9      AFG      Asia  Afghanistan  2020-03-04          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# ...

# %%
CovidWorld = pd.read_csv("D:\\Work\\Dự án Đh Kyungpook\\Tuan4\\Data\\owid-covid-data.csv",
                         usecols = ['location','date','total_cases','total_deaths','people_vaccinated','population'])
display(CovidWorld.head(-10))
print(f"Min total_cases in world: {CovidWorld['total_cases'].min()}")
print(f"Max total_cases in world: {CovidWorld['total_cases'].max()}")
GroupbyCountry = CovidWorld[['location','total_cases','total_deaths']].groupby('location').sum()

#ToCSVWorld = GroupbyCountry.to_csv("D:\\Work\\Dự án Đh Kyungpook\\Tuan4\\Data\\Các nước\\World.csv")
# Out:
#            location        date  total_cases  total_deaths  people_vaccinated  \
# 0       Afghanistan  2020-02-24          5.0           NaN                NaN
# 1       Afghanistan  2020-02-25          5.0           NaN                NaN
# 2       Afghanistan  2020-02-26          5.0           NaN                NaN
# 3       Afghanistan  2020-02-27          5.0           NaN                NaN
# 4       Afghanistan  2020-02-28          5.0           NaN                NaN
# ...             ...         ...          ...           ...                ...
# 136448     Zimbabwe  2021-11-14     133428.0        4696.0          3469198.0
# 136449     Zimbabwe  2021-11-15     133438.0        4697.0          3484207.0
# 136450     Zimbabwe  2021-11-16     133505.0        4698.0          3515140.0
# 136451     Zimbabwe  2021-11-17     133557.0        4699.0                NaN
# 136452     Zimbabwe  2021-11-18     133593.0        4699.0          3583256.0
#
#         population
# ...

# %%
CovidWorld1 = CovidWorld[CovidWorld['location'] == "World"]
display(CovidWorld1.head(-10))
ToCSVWorld = CovidWorld1.to_csv("D:\\Work\\Dự án Đh Kyungpook\\Tuan4\\Data\\Các nước\\World.csv",index = False)
# Out:
#         iso_code continent location        date  total_cases  new_cases  \
# 133948  OWID_WRL       NaN    World  2020-01-22        557.0        0.0
# 133949  OWID_WRL       NaN    World  2020-01-23        655.0       98.0
# 133950  OWID_WRL       NaN    World  2020-01-24        941.0      286.0
# 133951  OWID_WRL       NaN    World  2020-01-25       1434.0      493.0
# 133952  OWID_WRL       NaN    World  2020-01-26       2118.0      684.0
# ...          ...       ...      ...         ...          ...        ...
# 134610  OWID_WRL       NaN    World  2021-11-14  253770095.0   351443.0
# 134611  OWID_WRL       NaN    World  2021-11-15  254310598.0   540503.0
# 134612  OWID_WRL       NaN    World  2021-11-16  254837039.0   526441.0
# 134613  OWID_WRL       NaN    World  2021-11-17  255461905.0   624866.0
# 134614  OWID_WRL       NaN    World  2021-11-18  256075033.0   613128.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
#D:\Work\Dự án Đh Kyungpook\Tuan4\Data\Các nước

# %%
#Vietnam
CovidVietnam = CovidWorld[CovidWorld['location'] == 'Vietnam']
print(f"Min total_cases in Viet Nam: {CovidVietnam['total_cases'].min()}")
print(f"Max total_cases in Viet Nam: {CovidVietnam['total_cases'].max()}")
print(f"Population: {CovidVietnam['population'].unique()}")
display(CovidVietnam.head(-10))
ToCSVVN = CovidVietnam.to_csv("D:\\Work\\Dự án Đh Kyungpook\\Tuan4\\Data\\Các nước\\Vietnam.csv", index = False)
# Out:
# Min total_cases in Viet Nam: 2.0
# Max total_cases in Viet Nam: 1210340.0
# Population: [98168829.]
#        location        date  total_cases  total_deaths  people_vaccinated  \
# 133027  Vietnam  2020-01-23          2.0           NaN                NaN
# 133028  Vietnam  2020-01-24          2.0           NaN                NaN
# 133029  Vietnam  2020-01-25          2.0           NaN                NaN
# 133030  Vietnam  2020-01-26          2.0           NaN                NaN
# 133031  Vietnam  2020-01-27          2.0           NaN                NaN
# ...         ...         ...          ...           ...                ...
# 133688  Vietnam  2021-11-14    1026522.0       23082.0         64467940.0
# 133689  Vietnam  2021-11-15    1035138.0       23183.0         64767521.0
# 133690  Vietnam  2021-11-16    1045397.0       23270.0         65222953.0
# 133691  Vietnam  2021-11-17    1055246.0       23337.0         65772961.0
# ...

# %%
#Korea

# %%
CovidKorea = CovidWorld[CovidWorld['location'] == 'South Korea']
display(CovidKorea.head(-10))
print(f"Min total_cases in Viet Nam: {CovidKorea['total_cases'].min()}")
print(f"Max total_cases in Viet Nam: {CovidKorea['total_cases'].max()}")
print(f"Population: {CovidKorea['population'].unique()}")
ToCSVS_KOREA = CovidKorea.to_csv("D:\\Work\\Dự án Đh Kyungpook\\Tuan4\\Data\\Các nước\\South Korea.csv",index = False)
# Out:
#            location        date  total_cases  total_deaths  people_vaccinated  \
# 113670  South Korea  2020-01-21          NaN           NaN                NaN
# 113671  South Korea  2020-01-22          1.0           NaN                NaN
# 113672  South Korea  2020-01-23          1.0           NaN                NaN
# 113673  South Korea  2020-01-24          2.0           NaN                NaN
# 113674  South Korea  2020-01-25          2.0           NaN                NaN
# ...             ...         ...          ...           ...                ...
# 114333  South Korea  2021-11-14     397466.0        3115.0         41981590.0
# 114334  South Korea  2021-11-15     399591.0        3137.0         42044129.0
# 114335  South Korea  2021-11-16     402775.0        3158.0         42078118.0
# 114336  South Korea  2021-11-17     406065.0        3187.0         42124051.0
# 114337  South Korea  2021-11-18     409099.0        3215.0         42169435.0
#
#         population
# ...

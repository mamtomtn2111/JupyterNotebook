# %%
import pandas as pd
import numpy as np

# %%
UserNguPhap = pd.read_excel("C:\\Users\\mamto\\Desktop\\DataExcelProject1\\ManageNguPhap_eighteen_tlb_ketquanguphap.xlsx")
UserNguPhap
# Out:
#     id  userid    trinhdo                                      phanloai  \
# 0    1       1     Sơ cấp                      1, Liệt kê và tương phản
# 1    2       1     Sơ cấp                         2, Cấu trúc thời gian
# 2    4       1     Sơ cấp  4, Yêu cầu và bổn phận, cho phép và cấm đoán
# 3    3       1     Sơ cấp                       3, Năng lực và khả năng
# 4    5       1     Sơ cấp                        5, Hy vọng và ước muốn
# 5    6       1     Sơ cấp                        5, Hy vọng và ước muốn
# 6    7       1  Trung Cấp             1, Diễn tả phỏng đoán và suy đoán
# 7    8       1  Trung Cấp                        4, Diễn tả nguyên nhân
# 8    9       1    Cao Cấp                5, Diễn tả tình huống giả định
# 9   10       1    Cao Cấp               4, Diễn tả lý do và nguyên nhân
# 10  11       1    Cao Cấp                        3, Diễn tả danh từ hoá
# 11  12       1    Cao Cấp                       2, Diễn tả sự trích dẫn
# ...

# %%
SoCap = UserNguPhap[UserNguPhap["trinhdo"] == "Sơ cấp"]
SoCapDiemCao = SoCap[SoCap["diem"] >= 60]
SoCapDiemCao
# Out:
#    id  userid trinhdo                  phanloai       ketqua  diem  \
# 0   1       1  Sơ cấp  1, Liệt kê và tương phản  1:t,2:f,3:t    80
# 3   3       1  Sơ cấp   3, Năng lực và khả năng  1:t,2:f,3:t    60
# 5   6       1  Sơ cấp    5, Hy vọng và ước muốn  1:t,2:f,3:t   100
#
#                  thoigian
# 0  2022-01-26 17:06:40+07
# 3  2022-01-26 17:06:40+07
# 5  2022-01-26 17:06:40+07
